# %%
import redis
from redis.commands.json.path import Path
from redis.commands.search.field import TextField, TagField
from redis.commands.search.index_definition import IndexDefinition, IndexType
from redis.commands.search.query import Query
import uuid
import datetime
import json

r = redis.Redis(host='redis-19205.c330.asia-south1-1.gce.redns.redis-cloud.com', port=19205,password='admin', decode_responses=True)

def create_index():
    try:
        r.ft("beneficiary_idx").create_index(
            fields=[
                TagField("$.beneficiaryId", as_name="beneficiaryId"),
                TagField("$.accountId", as_name="accountId"),
                TagField("$.customerId", as_name="customerId"),
                TextField("$.name", as_name="name"),
                TextField("$.bankName", as_name="bankName"),
                TextField("$.ifsc", as_name="ifsc"),
                TagField("$.mobile", as_name="mobile"),
                TagField("$.type", as_name="type"),
                TextField("$.dateAdded", as_name="dateAdded")
            ],
            definition=IndexDefinition(prefix=["beneficiary:"], index_type=IndexType.JSON)
        )
    except Exception as e:
        print(f"Index already exists or error: {e}")

def add_or_update_beneficiary(customer_id, data):
    beneficiary_id = data.get("beneficiaryId") or str(uuid.uuid4())
    key = f"beneficiary:{customer_id}:{beneficiary_id}"
    data["beneficiaryId"] = beneficiary_id
    data["customerId"] = customer_id
    data["dateAdded"] = data.get("dateAdded") or datetime.datetime.utcnow().isoformat()
    r.json().set(key, Path.root_path(), data)
    return beneficiary_id

def delete_beneficiary(customer_id, beneficiary_id):
    key = f"beneficiary:{customer_id}:{beneficiary_id}"
    return r.delete(key)

def quick_search(term, limit=10):
    q = Query(f"@name:{term}* | @ifsc:{term}* | @mobile:{term}*").paging(0, limit)
    return r.ft("beneficiary_idx").search(q).docs

def advanced_search(customer_id=None, bank=None, type=None, limit=10):
    query_parts = []
    if customer_id:
        query_parts.append(f"@customerId:{{{customer_id}}}")
    if bank:
        query_parts.append(f"@bankName:{bank}")
    if type:
        query_parts.append(f"@type:{{{type}}}")
    final_query = " ".join(query_parts) or "*"
    q = Query(final_query).paging(0, limit)
    print(q)
    return r.ft("beneficiary_idx").search(q).docs

def load_dummy_data():
    data_samples = [
        {"name": "Ravi Mehta", "bankName": "HDFC Bank", "ifsc": "HDFC0000123", "mobile": "9876543210", "type": "internal", "accountId": "acc001"},
        {"name": "Anjali Rao", "bankName": "SBI", "ifsc": "SBIN0000456", "mobile": "9123456789", "type": "external", "accountId": "acc001"},
        {"name": "Rohit Das", "bankName": "ICICI", "ifsc": "ICIC0000789", "mobile": "9988776655", "type": "internal", "accountId": "acc002"},
        {"name": "Subhash Kumar", "bankName": "HDFC Bank", "ifsc": "HDFC0000003", "mobile": "9876543410", "type": "internal", "accountId": "acc001"},
        {"name": "Anil Rao", "bankName": "SBI", "ifsc": "SBIN0000006", "mobile": "9123456489", "type": "external", "accountId": "acc001"},
        {"name": "Rohit Das", "bankName": "ICICI", "ifsc": "ICIC0000700", "mobile": "9988776455", "type": "internal", "accountId": "acc002"},
    ]
    for record in data_samples:
        add_or_update_beneficiary("cust001", record)

if __name__ == "__main__":
    create_index()
    load_dummy_data()

    print("\n🔍 Quick Search for 'Ravi'")
    results = quick_search("Ravi")
    for re in results:
        print(json.dumps(re.__dict__, indent=2))

    print("\n🔎 Advanced Search for internal type")
    adv_results = advanced_search(customer_id="cust001", type="internal")
    for re in adv_results:
        print(json.dumps(re.__dict__, indent=2))
# Out:
# Index already exists or error: Index already exists
#
# 🔍 Quick Search for 'Ravi'
# {
#   "id": "beneficiary:cust001:85d1fb14-a014-42ad-a475-2226a66dbc23",
#   "payload": null,
#   "json": "{\"name\":\"Ravi Mehta\",\"bankName\":\"HDFC Bank\",\"ifsc\":\"HDFC0000123\",\"mobile\":\"9876543210\",\"type\":\"internal\",\"accountId\":\"acc001\",\"beneficiaryId\":\"85d1fb14-a014-42ad-a475-2226a66dbc23\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T05:52:39.474539\"}"
# }
# {
#   "id": "beneficiary:cust001:9cbec4fd-a6a3-4793-9c8e-43350c5c7536",
#   "payload": null,
#   "json": "{\"name\":\"Ravi Mehta\",\"bankName\":\"HDFC Bank\",\"ifsc\":\"HDFC0000123\",\"mobile\":\"9876543210\",\"type\":\"internal\",\"accountId\":\"acc001\",\"beneficiaryId\":\"9cbec4fd-a6a3-4793-9c8e-43350c5c7536\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T05:53:59.693585\"}"
# }
# {
#   "id": "beneficiary:cust001:d4c15a6a-46d7-46f3-93ec-0e60fb338ce7",
#   "payload": null,
#   "json": "{\"name\":\"Ravi Mehta\",\"bankName\":\"HDFC Bank\",\"ifsc\":\"HDFC0000123\",\"mobile\":\"9876543210\",\"type\":\"internal\",\"accountId\":\"acc001\",\"beneficiaryId\":\"d4c15a6a-46d7-46f3-93ec-0e60fb338ce7\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T05:55:31.011106\"}"
# }
# {
#   "id": "beneficiary:cust001:d5e80061-c3ac-4f1d-a07c-c4deaffe5fa7",
#   "payload": null,
#   "json": "{\"name\":\"Ravi Mehta\",\"bankName\":\"HDFC Bank\",\"ifsc\":\"HDFC0000123\",\"mobile\":\"9876543210\",\"type\":\"internal\",\"accountId\":\"acc001\",\"beneficiaryId\":\"d5e80061-c3ac-4f1d-a07c-c4deaffe5fa7\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T06:00:11.735643\"}"
# }
# {
#   "id": "beneficiary:cust001:21bef574-229d-4df2-877a-79e23897fcbd",
#   "payload": null,
#   "json": "{\"name\":\"Ravi Mehta\",\"bankName\":\"HDFC Bank\",\"ifsc\":\"HDFC0000123\",\"mobile\":\"9876543210\",\"type\":\"internal\",\"accountId\":\"acc001\",\"beneficiaryId\":\"21bef574-229d-4df2-877a-79e23897fcbd\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T06:01:23.085780\"}"
# }
# {
#   "id": "beneficiary:cust001:b3f0c392-f892-4f78-9984-7570a2100eb2",
#   "payload": null,
#   "json": "{\"name\":\"Ravi Mehta\",\"bankName\":\"HDFC Bank\",\"ifsc\":\"HDFC0000123\",\"mobile\":\"9876543210\",\"type\":\"internal\",\"accountId\":\"acc001\",\"beneficiaryId\":\"b3f0c392-f892-4f78-9984-7570a2100eb2\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T06:01:38.375571\"}"
# }
# {
#   "id": "beneficiary:cust001:19c37919-bde2-442e-9959-f8aeb3eb0ec7",
#   "payload": null,
#   "json": "{\"name\":\"Ravi Mehta\",\"bankName\":\"HDFC Bank\",\"ifsc\":\"HDFC0000123\",\"mobile\":\"9876543210\",\"type\":\"internal\",\"accountId\":\"acc001\",\"beneficiaryId\":\"19c37919-bde2-442e-9959-f8aeb3eb0ec7\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T06:02:11.223937\"}"
# }
# {
#   "id": "beneficiary:cust001:a44e3387-8a7b-471a-9ea3-4d9ce8cb4783",
#   "payload": null,
#   "json": "{\"name\":\"Ravi Mehta\",\"bankName\":\"HDFC Bank\",\"ifsc\":\"HDFC0000123\",\"mobile\":\"9876543210\",\"type\":\"internal\",\"accountId\":\"acc001\",\"beneficiaryId\":\"a44e3387-8a7b-471a-9ea3-4d9ce8cb4783\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T06:03:39.584237\"}"
# }
# {
#   "id": "beneficiary:cust001:dc27db3b-5fe8-4c11-986b-88d17ca05047",
#   "payload": null,
#   "json": "{\"name\":\"Ravi Mehta\",\"bankName\":\"HDFC Bank\",\"ifsc\":\"HDFC0000123\",\"mobile\":\"9876543210\",\"type\":\"internal\",\"accountId\":\"acc001\",\"beneficiaryId\":\"dc27db3b-5fe8-4c11-986b-88d17ca05047\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T06:05:09.117033\"}"
# }
# {
#   "id": "beneficiary:cust001:1f2ec142-a8f4-453d-9f6a-3647aac47025",
#   "payload": null,
#   "json": "{\"name\":\"Ravi Mehta\",\"bankName\":\"HDFC Bank\",\"ifsc\":\"HDFC0000123\",\"mobile\":\"9876543210\",\"type\":\"internal\",\"accountId\":\"acc001\",\"beneficiaryId\":\"1f2ec142-a8f4-453d-9f6a-3647aac47025\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T05:55:07.801937\"}"
# }
#
# 🔎 Advanced Search for internal type
# <redis.commands.search.query.Query object at 0x10715fdf0>
# {
#   "id": "beneficiary:cust001:85d1fb14-a014-42ad-a475-2226a66dbc23",
#   "payload": null,
#   "json": "{\"name\":\"Ravi Mehta\",\"bankName\":\"HDFC Bank\",\"ifsc\":\"HDFC0000123\",\"mobile\":\"9876543210\",\"type\":\"internal\",\"accountId\":\"acc001\",\"beneficiaryId\":\"85d1fb14-a014-42ad-a475-2226a66dbc23\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T05:52:39.474539\"}"
# }
# {
#   "id": "beneficiary:cust001:afebbca4-fe87-4028-99ca-28505269337b",
#   "payload": null,
#   "json": "{\"name\":\"Rohit Das\",\"bankName\":\"ICICI\",\"ifsc\":\"ICIC0000789\",\"mobile\":\"9988776655\",\"type\":\"internal\",\"accountId\":\"acc002\",\"beneficiaryId\":\"afebbca4-fe87-4028-99ca-28505269337b\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T05:52:39.506769\"}"
# }
# {
#   "id": "beneficiary:cust001:97c24163-f748-4e61-90e3-59d791a41edc",
#   "payload": null,
#   "json": "{\"name\":\"Subhash Kumar\",\"bankName\":\"HDFC Bank\",\"ifsc\":\"HDFC0000003\",\"mobile\":\"9876543410\",\"type\":\"internal\",\"accountId\":\"acc004\",\"beneficiaryId\":\"97c24163-f748-4e61-90e3-59d791a41edc\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T05:52:39.525970\"}"
# }
# {
#   "id": "beneficiary:cust001:2e4a3f1c-7a67-4dca-b685-8e7fa18d2a01",
#   "payload": null,
#   "json": "{\"name\":\"Piyush Das\",\"bankName\":\"ICICI\",\"ifsc\":\"ICIC0000700\",\"mobile\":\"9988776455\",\"type\":\"internal\",\"accountId\":\"acc002\",\"beneficiaryId\":\"2e4a3f1c-7a67-4dca-b685-8e7fa18d2a01\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T05:52:39.570746\"}"
# }
# {
#   "id": "beneficiary:cust001:9cbec4fd-a6a3-4793-9c8e-43350c5c7536",
#   "payload": null,
#   "json": "{\"name\":\"Ravi Mehta\",\"bankName\":\"HDFC Bank\",\"ifsc\":\"HDFC0000123\",\"mobile\":\"9876543210\",\"type\":\"internal\",\"accountId\":\"acc001\",\"beneficiaryId\":\"9cbec4fd-a6a3-4793-9c8e-43350c5c7536\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T05:53:59.693585\"}"
# }
# {
#   "id": "beneficiary:cust001:bfe23901-f1b7-440d-8f74-48c2fef594eb",
#   "payload": null,
#   "json": "{\"name\":\"Rohit Das\",\"bankName\":\"ICICI\",\"ifsc\":\"ICIC0000789\",\"mobile\":\"9988776655\",\"type\":\"internal\",\"accountId\":\"acc002\",\"beneficiaryId\":\"bfe23901-f1b7-440d-8f74-48c2fef594eb\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T05:53:59.721087\"}"
# }
# {
#   "id": "beneficiary:cust001:de9759a1-c15d-4944-b18b-29c7dcf4d1cb",
#   "payload": null,
#   "json": "{\"name\":\"Subhash Kumar\",\"bankName\":\"HDFC Bank\",\"ifsc\":\"HDFC0000003\",\"mobile\":\"9876543410\",\"type\":\"internal\",\"accountId\":\"acc004\",\"beneficiaryId\":\"de9759a1-c15d-4944-b18b-29c7dcf4d1cb\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T05:53:59.733152\"}"
# }
# {
#   "id": "beneficiary:cust001:6e15c188-32fe-4044-a7c0-f61243a15c94",
#   "payload": null,
#   "json": "{\"name\":\"Piyush Das\",\"bankName\":\"ICICI\",\"ifsc\":\"ICIC0000700\",\"mobile\":\"9988776455\",\"type\":\"internal\",\"accountId\":\"acc002\",\"beneficiaryId\":\"6e15c188-32fe-4044-a7c0-f61243a15c94\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T05:53:59.762742\"}"
# }
# {
#   "id": "beneficiary:cust001:d4c15a6a-46d7-46f3-93ec-0e60fb338ce7",
#   "payload": null,
#   "json": "{\"name\":\"Ravi Mehta\",\"bankName\":\"HDFC Bank\",\"ifsc\":\"HDFC0000123\",\"mobile\":\"9876543210\",\"type\":\"internal\",\"accountId\":\"acc001\",\"beneficiaryId\":\"d4c15a6a-46d7-46f3-93ec-0e60fb338ce7\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T05:55:31.011106\"}"
# }
# {
#   "id": "beneficiary:cust001:16e407b5-3604-4d74-babb-a5f5d36d44d3",
#   "payload": null,
#   "json": "{\"name\":\"Rohit Das\",\"bankName\":\"ICICI\",\"ifsc\":\"ICIC0000789\",\"mobile\":\"9988776655\",\"type\":\"internal\",\"accountId\":\"acc002\",\"beneficiaryId\":\"16e407b5-3604-4d74-babb-a5f5d36d44d3\",\"customerId\":\"cust001\",\"dateAdded\":\"2025-07-29T05:55:31.040319\"}"
# }
